# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Objectives" data-toc-modified-id="Objectives-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Objectives</a></span></li><li><span><a href="#What-is-Pandas?" data-toc-modified-id="What-is-Pandas?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>What is Pandas?</a></span><ul class="toc-item"><li><span><a href="#Accessing-Data" data-toc-modified-id="Accessing-Data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Accessing Data</a></span></li><li><span><a href="#DataFrames-and-Series" data-toc-modified-id="DataFrames-and-Series-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>DataFrames and Series</a></span></li><li><span><a href="#More-Basic-DataFrame-Attributes-and-Methods" data-toc-modified-id="More-Basic-DataFrame-Attributes-and-Methods-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>More Basic DataFrame Attributes and Methods</a></span><ul class="toc-item"><li><span><a href="#.head()-:-first-5-rows" data-toc-modified-id=".head()-:-first-5-rows-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span><code>.head()</code> : first 5 rows</a></span></li><li><span><a href="#.tail()-:-last-5-rows" data-toc-modified-id=".tail()-:-last-5-rows-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span><code>.tail()</code> : last 5 rows</a></span></li><li><span><a href="#.info()-:-information-about-the-columns,-including-about-nulls-in-those-columns" data-toc-modified-id=".info()-:-information-about-the-columns,-including-about-nulls-in-those-columns-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span><code>.info()</code> : information about the columns, including about nulls in those columns</a></span></li><li><span><a href="#.describe()-:-statistics-about-the-data" data-toc-modified-id=".describe()-:-statistics-about-the-data-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span><code>.describe()</code> : statistics about the data</a></span></li><li><span><a href="#.dtypes-:-data-types-of-each-column" data-toc-modified-id=".dtypes-:-data-types-of-each-column-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span><code>.dtypes</code> : data types of each column</a></span></li><li><span><a href="#.shape-:-number-of-rows-and-columns" data-toc-modified-id=".shape-:-number-of-rows-and-columns-2.3.6"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span><code>.shape</code> : number of rows and columns</a></span></li><li><span><a href="#Statistics" data-toc-modified-id="Statistics-2.3.7"><span class="toc-item-num">2.3.7&nbsp;&nbsp;</span>Statistics</a></span></li></ul></li><li><span><a href="#Enough-With-The-Small-Stuff---Bring-On-Real-Data!" data-toc-modified-id="Enough-With-The-Small-Stuff---Bring-On-Real-Data!-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Enough With The Small Stuff - Bring On Real Data!</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Any-Observations?" data-toc-modified-id="Any-Observations?-2.4.0.1"><span class="toc-item-num">2.4.0.1&nbsp;&nbsp;</span>Any Observations?</a></span></li></ul></li></ul></li><li><span><a href="#Adding-to-a-DataFrame" data-toc-modified-id="Adding-to-a-DataFrame-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Adding to a DataFrame</a></span><ul class="toc-item"><li><span><a href="#Adding-Rows" data-toc-modified-id="Adding-Rows-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Adding Rows</a></span></li></ul></li><li><span><a href="#Adding-(and-Deleting)-Columns" data-toc-modified-id="Adding-(and-Deleting)-Columns-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Adding (and Deleting) Columns</a></span><ul class="toc-item"><li><span><a href="#DateTime-Data!" data-toc-modified-id="DateTime-Data!-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>DateTime Data!</a></span></li></ul></li></ul></li><li><span><a href="#Filtering" data-toc-modified-id="Filtering-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Filtering</a></span><ul class="toc-item"><li><span><a href="#.loc" data-toc-modified-id=".loc-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><code>.loc</code></a></span><ul class="toc-item"><li><span><a href="#Your-turn!" data-toc-modified-id="Your-turn!-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Your turn!</a></span><ul class="toc-item"><li><span><a href="#Exercise-1" data-toc-modified-id="Exercise-1-3.1.1.1"><span class="toc-item-num">3.1.1.1&nbsp;&nbsp;</span>Exercise 1</a></span></li><li><span><a href="#Exercise-2" data-toc-modified-id="Exercise-2-3.1.1.2"><span class="toc-item-num">3.1.1.2&nbsp;&nbsp;</span>Exercise 2</a></span></li></ul></li></ul></li><li><span><a href="#.iloc" data-toc-modified-id=".iloc-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><code>.iloc</code></a></span></li></ul></li><li><span><a href="#Series-Methods" data-toc-modified-id="Series-Methods-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Series Methods</a></span><ul class="toc-item"><li><span><a href="#.value_counts()" data-toc-modified-id=".value_counts()-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><code>.value_counts()</code></a></span></li><li><span><a href="#.sort_values()" data-toc-modified-id=".sort_values()-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span><code>.sort_values()</code></a></span></li></ul></li><li><span><a href="#Extra-Credit:-Find-a-.csv-file-online-and-experiment-with-it." data-toc-modified-id="Extra-Credit:-Find-a-.csv-file-online-and-experiment-with-it.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Extra Credit: Find a .csv file online and experiment with it.</a></span></li></ul></div>

# %% [markdown]
# ![pandas](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/2880px-Pandas_logo.svg.png)

# %% [markdown]
# # Objectives

# %% [markdown]
# - Load .csv files into `pandas` DataFrames
# - Describe and manipulate data in Series and DataFrames

# %% [markdown]
# # What is Pandas?

# %% [markdown]
# ![I have no idea what I'm doing panda](https://cdn-images-1.medium.com/max/1600/1*oBx032ncOwLmCFX3Epo3Zg.jpeg)
#
# Just kidding - not actual literal pandas.

# %% [markdown]
# Pandas, as [the Anaconda docs](https://docs.anaconda.com/anaconda/packages/py3.7_osx-64/) tell us, offers us "High-performance, easy-to-use data structures and data analysis tools." It's something like "Excel for Python", but it's quite a bit more powerful. The name comes from "panel data", a common way to describe the kind of multidimensional data we'll be working with in certain academic circles (namely, statistics and econometrics) [[Source]](https://www.dlr.de/sc/Portaldata/15/Resources/dokumente/pyhpc2011/submissions/pyhpc2011_submission_9.pdf)
#
# In order to use pandas, we'll need to import it into our notebook first.

# %%
# Import - using the common alias
import pandas as pd

# %% [markdown]
# ## Accessing Data
#
# ![pandas documentation image showcasing the kinds of data it can both read and write to](https://pandas.pydata.org/docs/_images/02_io_readwrite.svg)
#
# [[Image Source]](https://pandas.pydata.org/docs/getting_started/intro_tutorials/02_read_write.html)

# %% [markdown]
# Pandas can access a ton of different data types, including some that should be familiar: CSVs and JSONs! That's right, no more `with` / `open` statements now that we're using pandas!
#
# Most of the time, we'll see CSVs - so let's access a 'toy' data set quickly just to familiarize ourselves with using pandas. There's a heart dataset available in the data folder on this repository - let's read that in.

# %%
# !ls data
# Out:
# 2019_Census_US_Population_Data_By_State_Lat_Long.csv
# Austin_Animal_Center_Intakes-clean-year.csv
# Austin_Animal_Center_Intakes_022822.csv
# Austin_Animal_Center_Outcomes_022822.csv
# BankChurners.csv
# Datafiniti_Fast_Food.csv
# OpenFoodFacts.csv
# bundesliga.csv
# classic-rock-song-list.csv
# ds_chars.csv
# heart.csv
# new_releases.json
# plants.json
# pop_soda_data.csv
# preferences.csv
# states.csv

# %%
# Use read_csv to read in the heart csv file
# Need to assign it to a variable too - let's call this heart_df
heart_df = pd.read_csv('data/heart.csv')

# %% [markdown]
# The output of the `.read_csv()` function is a pandas *DataFrame*, which has a familiar tabaular structure of rows and columns.

# %%
# Let's check this variable out
heart_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# What type is this variable?
type(heart_df['age'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## DataFrames and Series

# %% [markdown]
# Two main types of pandas objects are the DataFrame and the Series, the latter being in effect a single column of the former:

# %%
# Let's grab just one column

heart_df[['age','sex']]
# Out:
#      age  sex
# 0     63    1
# 1     37    1
# 2     41    0
# 3     56    1
# 4     57    0
# ..   ...  ...
# 298   57    0
# 299   45    1
# 300   68    1
# 301   57    1
# 302   57    0
#
# [303 rows x 2 columns]

# %% [markdown]
# Notice how we can isolate a column of our DataFrame simply by using square brackets together with the name of the column. We can also access columns as an attribute of the DataFrame - but that only works if the name of the column doesn't have any spaces or weird characters!

# %%
# Grab the same column as an attribute
heart_df.age
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
# What type is the column?
type(df.age)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Both Series and DataFrames have an *index* as well:

# %%
# Check out the dataframe index
df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
# Check out the series index
df.age.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %% [markdown]
# DataFrames have columns - but a Series is just a single column, so it doesn't have the columns attribute.

# %%
# Check out the dataframe columns
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# Now try with the series
df.age.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Now try with the series
# ----> 2 df.age.columns
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %% [markdown]
# Pandas is built on top of NumPy, and we can always access the NumPy array underlying a DataFrame using `.values`.

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# Check out the dataframe values
df.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %% [markdown]
# ## More Basic DataFrame Attributes and Methods

# %% [markdown]
# ### `.head()` : first 5 rows

# %%
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ### `.tail()` : last 5 rows

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %% [markdown]
# ### `.info()` : information about the columns, including about nulls in those columns

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ### `.describe()` : statistics about the data

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# ### `.dtypes` : data types of each column

# %%
df.age.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### `.shape` : number of rows and columns

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# ### Statistics
#
# We saw them above, in the `.describe`, but we can also calculate statistics by calling them individually.

# %%
# Calculate the mean - for the whole dataframe!
df.mean()
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %% [markdown]
# Let's pause and interpret - any observations?
#
# -

# %%
# Now min
df.age.min()
# Out:
# 29

# %%
# And max
df.age.max()
# Out:
# 77

# %% [markdown]
# ## Enough With The Small Stuff - Bring On Real Data!
#
# Let's access an open data portal and get some real live data!

# %% [markdown]
# Austin Animal Center Intake Data: https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm/

# %%
# Accessing a CSV from a url
intakes_url = pd.read_json('https://data.austintexas.gov/resource/wter-evkm.json')
intakes_url
# Out:
#     animal_id          name            datetime                datetime2  \
# 0     A786884        *Brock 2019-01-03 16:19:00  2019-01-03T16:19:00.000
# 1     A706918         Belle 2015-07-05 12:59:00  2015-07-05T12:59:00.000
# 2     A724273       Runster 2016-04-14 18:43:00  2016-04-14T18:43:00.000
# 3     A857105  Johnny Ringo 2022-05-12 00:23:00  2022-05-12T00:23:00.000
# 4     A682524           Rio 2014-06-29 10:38:00  2014-06-29T10:38:00.000
# ..        ...           ...                 ...                      ...
# 995   A777067           NaN 2018-07-23 08:34:00  2018-07-23T08:34:00.000
# 996   A728317         Cesar 2016-06-02 11:50:00  2016-06-02T11:50:00.000
# 997   A694323        *Mateo 2014-12-25 21:40:00  2014-12-25T21:40:00.000
# 998   A694323        *Mateo 2023-06-21 12:12:00  2023-06-21T12:12:00.000
# 999   A706404           Xan 2015-06-28 15:06:00  2015-06-28T15:06:00.000
#
#                              found_location      intake_type intake_condition  \
# 0       2501 Magin Meadow Dr in Austin (TX)            Stray           Normal
# 1          9409 Bluegrass Dr in Austin (TX)            Stray           Normal
# 2        2818 Palomino Trail in Austin (TX)            Stray           Normal
# 3        4404 Sarasota Drive in Austin (TX)    Public Assist           Normal
# 4             800 Grove Blvd in Austin (TX)            Stray           Normal
# ..                                      ...              ...              ...
# 995  Turnersville And Parmer in Travis (TX)            Stray           Normal
# 996                             Austin (TX)  Owner Surrender           Normal
# 997      Duval Rd. & Hwy 183 in Austin (TX)            Stray           Normal
# 998           900 Gardner Rd in Austin (TX)            Stray           Normal
# 999             13300 Dessau in Austin (TX)            Stray          Injured
#
#     animal_type sex_upon_intake age_upon_intake  \
# 0           Dog   Neutered Male         2 years
# 1           Dog   Spayed Female         8 years
# 2           Dog     Intact Male       11 months
# 3           Cat   Neutered Male         2 years
# 4           Dog   Neutered Male         4 years
# ..          ...             ...             ...
# 995         Dog     Intact Male          1 year
# 996         Cat   Neutered Male         2 years
# 997         Dog     Intact Male         1 month
# 998         Dog   Neutered Male         8 years
# 999         Dog   Intact Female         2 years
#
#                                      breed         color
# 0                               Beagle Mix      Tricolor
# 1                 English Springer Spaniel   White/Liver
# 2                              Basenji Mix   Sable/White
# 3                       Domestic Shorthair  Orange Tabby
# 4    Doberman Pinsch/Australian Cattle Dog      Tan/Gray
# ..                                     ...           ...
# 995                    Standard Poodle Mix     Chocolate
# 996                 Domestic Shorthair Mix   Brown Tabby
# 997                 Labrador Retriever Mix          Buff
# 998                 Labrador Retriever Mix          Buff
# 999                        German Shepherd   Black/Brown
#
# [1000 rows x 12 columns]

# %%
# Same as the JSON output from this API endpoint, but different levels of detail for dates!
intakes_url.shape
# Out:
# (1000, 12)

# %%
# But this is only 1000 rows... website says there's 136K rows!

# %%
# It's a limitation of the API - let's just download the data instead
# It's in the data folder

intakes_url = pd.read_csv('data/Austin_Animal_Center_Intakes-clean-year.csv')
intakes_url
# Out:
#        Animal ID     Name             DateTime  Year  \
# 0        A786884   *Brock  2019-01-03 16:19:00  2019
# 1        A706918    Belle  2015-07-05 12:59:00  2015
# 2        A724273  Runster  2016-04-14 18:43:00  2016
# 3        A665644      NaN  2013-10-21 07:59:00  2013
# 4        A682524      Rio  2014-06-29 10:38:00  2014
# ...          ...      ...                  ...   ...
# 136758   A852238  A852238  2022-02-28 14:02:00  2022
# 136759   A852221     Coco  2022-02-28 11:05:00  2022
# 136760   A851977    *Jack  2022-02-22 13:34:00  2022
# 136761   A852127    Sonic  2022-02-25 13:05:00  2022
# 136762   A852194    Queen  2022-02-27 13:44:00  2022
#
#                                     Found Location Intake Type  \
# 0              2501 Magin Meadow Dr in Austin (TX)       Stray
# 1                 9409 Bluegrass Dr in Austin (TX)       Stray
# 2               2818 Palomino Trail in Austin (TX)       Stray
# 3                                      Austin (TX)       Stray
# 4                    800 Grove Blvd in Austin (TX)       Stray
# ...                                            ...         ...
# 136758  Cameron And Crosspark Drive in Austin (TX)       Stray
# 136759                   45 And 183 in Travis (TX)       Stray
# 136760        1200 Montopolis Drive in Austin (TX)       Stray
# 136761      7601 Daffan Ln Unit 424 in Austin (TX)       Stray
# 136762            8071 N Lamar Blvd in Austin (TX)       Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136758           Normal         Dog   Intact Female        6 months
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
#
#                                         Breed         Color
# 0                                  Beagle Mix      Tricolor
# 1                    English Springer Spaniel   White/Liver
# 2                                 Basenji Mix   Sable/White
# 3                      Domestic Shorthair Mix        Calico
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray
# ...                                       ...           ...
# 136758                 Labrador Retriever Mix   Black/White
# 136759                         Great Pyrenees         White
# 136760          Chihuahua Shorthair/Dachshund   Black/White
# 136761                           Pit Bull Mix  White/Yellow
# 136762                             Cane Corso    Blue Cream
#
# [136763 rows x 12 columns]

# %%
# Now let's explore those earlier attributes and methods on this dataset!
# Check the first 5 rows
intakes_url.head()
# Out:
#   Animal ID     Name             DateTime  Year  \
# 0   A786884   *Brock  2019-01-03 16:19:00  2019
# 1   A706918    Belle  2015-07-05 12:59:00  2015
# 2   A724273  Runster  2016-04-14 18:43:00  2016
# 3   A665644      NaN  2013-10-21 07:59:00  2013
# 4   A682524      Rio  2014-06-29 10:38:00  2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
# Check the last 5 rows
intakes_url.tail()
# Out:
#        Animal ID     Name             DateTime  Year  \
# 136758   A852238  A852238  2022-02-28 14:02:00  2022
# 136759   A852221     Coco  2022-02-28 11:05:00  2022
# 136760   A851977    *Jack  2022-02-22 13:34:00  2022
# 136761   A852127    Sonic  2022-02-25 13:05:00  2022
# 136762   A852194    Queen  2022-02-27 13:44:00  2022
#
#                                     Found Location Intake Type  \
# 136758  Cameron And Crosspark Drive in Austin (TX)       Stray
# 136759                   45 And 183 in Travis (TX)       Stray
# 136760        1200 Montopolis Drive in Austin (TX)       Stray
# 136761      7601 Daffan Ln Unit 424 in Austin (TX)       Stray
# 136762            8071 N Lamar Blvd in Austin (TX)       Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 136758           Normal         Dog   Intact Female        6 months
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
#
#                                 Breed         Color
# 136758         Labrador Retriever Mix   Black/White
# 136759                 Great Pyrenees         White
# 136760  Chihuahua Shorthair/Dachshund   Black/White
# 136761                   Pit Bull Mix  White/Yellow
# 136762                     Cane Corso    Blue Cream

# %%
# Check the shape
intakes_url.shape
# Out:
# (136763, 12)

# %%
# Check the datatypes
intakes_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136763 entries, 0 to 136762
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         136763 non-null  object
#  1   Name              95772 non-null   object
#  2   DateTime          136763 non-null  object
#  3   Year              136763 non-null  int64
#  4   Found Location    136763 non-null  object
#  5   Intake Type       136763 non-null  object
#  6   Intake Condition  136763 non-null  object
#  7   Animal Type       136763 non-null  object
#  8   Sex upon Intake   136762 non-null  object
#  9   Age upon Intake   136763 non-null  object
#  10  Breed             136763 non-null  object
#  11  Color             136763 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 12.5+ MB

# %%
# Check more general information on the dataframe
intakes_url.dtypes
# Out:
# Animal ID           object
# Name                object
# DateTime            object
# Year                 int64
# Found Location      object
# Intake Type         object
# Intake Condition    object
# Animal Type         object
# Sex upon Intake     object
# Age upon Intake     object
# Breed               object
# Color               object
# dtype: object

# %%
# Check summary/descriptive statistics on the dataframe
intakes_url.describe()
# Out:
#                 Year
# count  136763.000000
# mean     2017.100692
# std         2.328994
# min      2013.000000
# 25%      2015.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2022.000000

# %% [markdown]
# #### Any Observations?
#
# -

# %% [markdown]
# ## Adding to a DataFrame

# %% [markdown]
# ### Adding Rows

# %% [markdown]
# We have a new animal coming in, captured here in a Python dictionary:

# %%
# Dictionary, where keys match the column names and values are the row values
next_row = {'Animal ID': 'A851755',
            'Name': "T'Challa",
            'DateTime': '2/28/2022 11:25:00 AM',
            'MonthYear': 'February 2022',
            'Found Location': 'Houston (TX)',
            'Intake Type': 'Public Assist',
            'Intake Condition': 'Normal',
            'Animal Type': 'Cat',
            'Sex upon Intake': 'Neutered Male',
            'Age upon Intake': '4 years',
            'Breed': 'Domestic Shorthair',
            'Color': 'Black'}
next_row
# Out:
# {'Animal ID': 'A851755',
#  'Name': "T'Challa",
#  'DateTime': '2/28/2022 11:25:00 AM',
#  'MonthYear': 'February 2022',
#  'Found Location': 'Houston (TX)',
#  'Intake Type': 'Public Assist',
#  'Intake Condition': 'Normal',
#  'Animal Type': 'Cat',
#  'Sex upon Intake': 'Neutered Male',
#  'Age upon Intake': '4 years',
#  'Breed': 'Domestic Shorthair',
#  'Color': 'Black'}

# %% [markdown]
# How can we add this to the bottom of our dataset?

# %%
# Let's first turn this into a DataFrame.
# We can use the .from_dict() method.
new_animal = pd.DataFrame.from_dict(next_row, orient = 'index').T

# %%
new_animal
# Out:
#   Animal ID      Name               DateTime      MonthYear Found Location  \
# 0   A851755  T'Challa  2/28/2022 11:25:00 AM  February 2022   Houston (TX)
#
#      Intake Type Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0  Public Assist           Normal         Cat   Neutered Male         4 years
#
#                 Breed  Color
# 0  Domestic Shorthair  Black

# %%
# Now we just need to concatenate the two DataFrames together.
# Note the `ignore_index` parameter! We'll set that to True.
animals = pd.concat([intakes_url, new_animal], ignore_index = True)

# %%
# Let's check the end to make sure we were successful!
animals.tail(1)
# Out:
#        Animal ID      Name               DateTime  Year Found Location  \
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM   NaN   Houston (TX)
#
#           Intake Type Intake Condition Animal Type Sex upon Intake  \
# 136763  Public Assist           Normal         Cat   Neutered Male
#
#        Age upon Intake               Breed  Color      MonthYear  test
# 136763         4 years  Domestic Shorthair  Black  February 2022     0

# %% [markdown]
# ## Adding (and Deleting) Columns

# %% [markdown]
# Adding a column is very easy in `pandas`. Let's add a new column to our dataset called "test", and set all of its values to 0.

# %%
# Create a new column, 'test', where every value in the col is 0
animals['test'] = 0

# %%
# Sanity check
animals
# Out:
#        Animal ID      Name               DateTime    Year  \
# 0        A786884    *Brock    2019-01-03 16:19:00  2019.0
# 1        A706918     Belle    2015-07-05 12:59:00  2015.0
# 2        A724273   Runster    2016-04-14 18:43:00  2016.0
# 3        A665644       NaN    2013-10-21 07:59:00  2013.0
# 4        A682524       Rio    2014-06-29 10:38:00  2014.0
# ...          ...       ...                    ...     ...
# 136759   A852221      Coco    2022-02-28 11:05:00  2022.0
# 136760   A851977     *Jack    2022-02-22 13:34:00  2022.0
# 136761   A852127     Sonic    2022-02-25 13:05:00  2022.0
# 136762   A852194     Queen    2022-02-27 13:44:00  2022.0
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM     NaN
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color      MonthYear  \
# 0                                  Beagle Mix      Tricolor            NaN
# 1                    English Springer Spaniel   White/Liver            NaN
# 2                                 Basenji Mix   Sable/White            NaN
# 3                      Domestic Shorthair Mix        Calico            NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray            NaN
# ...                                       ...           ...            ...
# 136759                         Great Pyrenees         White            NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                           Pit Bull Mix  White/Yellow            NaN
# 136762                             Cane Corso    Blue Cream            NaN
# 136763                     Domestic Shorthair         Black  February 2022
#
#         test
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 136759     0
# 136760     0
# 136761     0
# 136762     0
# 136763     0
#
# [136764 rows x 14 columns]

# %% [markdown]
# But we don't need that - let's drop that column.

# %%
# Drop that test column
animals.drop(columns = ['test'], inplace = True)

# %%
# Sanity check
animals
# Out:
#        Animal ID      Name               DateTime    Year  \
# 0        A786884    *Brock    2019-01-03 16:19:00  2019.0
# 1        A706918     Belle    2015-07-05 12:59:00  2015.0
# 2        A724273   Runster    2016-04-14 18:43:00  2016.0
# 3        A665644       NaN    2013-10-21 07:59:00  2013.0
# 4        A682524       Rio    2014-06-29 10:38:00  2014.0
# ...          ...       ...                    ...     ...
# 136759   A852221      Coco    2022-02-28 11:05:00  2022.0
# 136760   A851977     *Jack    2022-02-22 13:34:00  2022.0
# 136761   A852127     Sonic    2022-02-25 13:05:00  2022.0
# 136762   A852194     Queen    2022-02-27 13:44:00  2022.0
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM     NaN
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color      MonthYear
# 0                                  Beagle Mix      Tricolor            NaN
# 1                    English Springer Spaniel   White/Liver            NaN
# 2                                 Basenji Mix   Sable/White            NaN
# 3                      Domestic Shorthair Mix        Calico            NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray            NaN
# ...                                       ...           ...            ...
# 136759                         Great Pyrenees         White            NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                           Pit Bull Mix  White/Yellow            NaN
# 136762                             Cane Corso    Blue Cream            NaN
# 136763                     Domestic Shorthair         Black  February 2022
#
# [136764 rows x 13 columns]

# %% [markdown]
# We can also do math with columns, or use mathematical notation to combine columns even when they aren't numerical!
#
# We don't have any numeric data in this current dataset. But we can still create a combined "Type" column that combines the values of our Intake Type and Animal Type columns.

# %%
# Create a new column, 'Type', from the two 'Type' columns
animals['type'] = animals['Intake Type'] + " " + animals['Animal Type']
animals['Years plus 5'] = animals['Year'] + 5

# %%
# Sanity check
animals.drop(columns = ['Years plus 5'],inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 2
#       1 # Sanity check
# ----> 2 animals.drop(columns = ['Years plus 5'],inplace = True)
#       3 animals
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Years plus 5'] not found in axis"

# %%
animals
# Out:
#        Animal ID      Name               DateTime    Year  \
# 0        A786884    *Brock    2019-01-03 16:19:00  2019.0
# 1        A706918     Belle    2015-07-05 12:59:00  2015.0
# 2        A724273   Runster    2016-04-14 18:43:00  2016.0
# 3        A665644       NaN    2013-10-21 07:59:00  2013.0
# 4        A682524       Rio    2014-06-29 10:38:00  2014.0
# ...          ...       ...                    ...     ...
# 136759   A852221      Coco    2022-02-28 11:05:00  2022.0
# 136760   A851977     *Jack    2022-02-22 13:34:00  2022.0
# 136761   A852127     Sonic    2022-02-25 13:05:00  2022.0
# 136762   A852194     Queen    2022-02-27 13:44:00  2022.0
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM     NaN
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color      MonthYear  \
# 0                                  Beagle Mix      Tricolor            NaN
# 1                    English Springer Spaniel   White/Liver            NaN
# 2                                 Basenji Mix   Sable/White            NaN
# 3                      Domestic Shorthair Mix        Calico            NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray            NaN
# ...                                       ...           ...            ...
# 136759                         Great Pyrenees         White            NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                           Pit Bull Mix  White/Yellow            NaN
# 136762                             Cane Corso    Blue Cream            NaN
# 136763                     Domestic Shorthair         Black  February 2022
#
#                      type
# 0               Stray Dog
# 1               Stray Dog
# 2               Stray Dog
# 3               Stray Cat
# 4               Stray Dog
# ...                   ...
# 136759          Stray Dog
# 136760          Stray Dog
# 136761          Stray Dog
# 136762          Stray Dog
# 136763  Public Assist Cat
#
# [136764 rows x 14 columns]

# %% [markdown]
# ### DateTime Data!
#
# Useful reference: https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html

# %% [markdown]
# I mentioned we don't have any numeric data in here... let's make a new numeric column! Specifically, let's grab the year from our `DateTime` column and use that to create a new `Year` column. AKA, let's learn how to deal with datetime data!

# %%
# What type is the DateTime column now?
animals.dtypes
# Out:
# Animal ID                   object
# Name                        object
# DateTime                    object
# Year                datetime64[ns]
# Found Location              object
# Intake Type                 object
# Intake Condition            object
# Animal Type                 object
# Sex upon Intake             object
# Age upon Intake             object
# Breed                       object
# Color                       object
# MonthYear                   object
# type                        object
# dtype: object

# %%
# Let's make that a datetime datatype
animals['Intake Year'] = pd.to_datetime(animals['DateTime'])

# %%
# Sanity check

# %%
# Now we can access parts of a datetime object using .dt - an attribute!
animals['Intake Year'] = animals['Intake Year'].dt.year

# %%
# Make that into a new column
animals['day of week'] = animals['Intake Year'].dt.dayofweek
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[127], line 2
#       1 # Make that into a new column
# ----> 2 animals['day of week'] = animals['Intake Year'].dt.dayofweek
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\accessors.py:512, in CombinedDatetimelikeProperties.__new__(cls, data)
#     509 elif is_period_dtype(data.dtype):
#     510     return PeriodProperties(data, orig)
# --> 512 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
# Sanity check
animals
# Out:
#        Animal ID      Name               DateTime                Year  \
# 0        A786884    *Brock    2019-01-03 16:19:00 2019-01-03 16:19:00
# 1        A706918     Belle    2015-07-05 12:59:00 2015-07-05 12:59:00
# 2        A724273   Runster    2016-04-14 18:43:00 2016-04-14 18:43:00
# 3        A665644       NaN    2013-10-21 07:59:00 2013-10-21 07:59:00
# 4        A682524       Rio    2014-06-29 10:38:00 2014-06-29 10:38:00
# ...          ...       ...                    ...                 ...
# 136759   A852221      Coco    2022-02-28 11:05:00 2022-02-28 11:05:00
# 136760   A851977     *Jack    2022-02-22 13:34:00 2022-02-22 13:34:00
# 136761   A852127     Sonic    2022-02-25 13:05:00 2022-02-25 13:05:00
# 136762   A852194     Queen    2022-02-27 13:44:00 2022-02-27 13:44:00
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM 2022-02-28 11:25:00
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color      MonthYear  \
# 0                                  Beagle Mix      Tricolor            NaN
# 1                    English Springer Spaniel   White/Liver            NaN
# 2                                 Basenji Mix   Sable/White            NaN
# 3                      Domestic Shorthair Mix        Calico            NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray            NaN
# ...                                       ...           ...            ...
# 136759                         Great Pyrenees         White            NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                           Pit Bull Mix  White/Yellow            NaN
# 136762                             Cane Corso    Blue Cream            NaN
# 136763                     Domestic Shorthair         Black  February 2022
#
#                      type  day of week  Intake Year
# 0               Stray Dog            3         2019
# 1               Stray Dog            6         2015
# 2               Stray Dog            3         2016
# 3               Stray Cat            0         2013
# 4               Stray Dog            6         2014
# ...                   ...          ...          ...
# 136759          Stray Dog            0         2022
# 136760          Stray Dog            1         2022
# 136761          Stray Dog            4         2022
# 136762          Stray Dog            6         2022
# 136763  Public Assist Cat            0         2022
#
# [136764 rows x 16 columns]

# %% [markdown]
# # Filtering

# %% [markdown]
# We can use filtering techniques to see only certain rows of our data. Let's look at only animals taken into the center during or after 2020:

# %%
animals.loc[animals['Intake Type'] == 'Stray']
# Out:
#        Animal ID     Name             DateTime                Year  \
# 0        A786884   *Brock  2019-01-03 16:19:00 2019-01-03 16:19:00
# 1        A706918    Belle  2015-07-05 12:59:00 2015-07-05 12:59:00
# 2        A724273  Runster  2016-04-14 18:43:00 2016-04-14 18:43:00
# 3        A665644      NaN  2013-10-21 07:59:00 2013-10-21 07:59:00
# 4        A682524      Rio  2014-06-29 10:38:00 2014-06-29 10:38:00
# ...          ...      ...                  ...                 ...
# 136758   A852238  A852238  2022-02-28 14:02:00 2022-02-28 14:02:00
# 136759   A852221     Coco  2022-02-28 11:05:00 2022-02-28 11:05:00
# 136760   A851977    *Jack  2022-02-22 13:34:00 2022-02-22 13:34:00
# 136761   A852127    Sonic  2022-02-25 13:05:00 2022-02-25 13:05:00
# 136762   A852194    Queen  2022-02-27 13:44:00 2022-02-27 13:44:00
#
#                                     Found Location Intake Type  \
# 0              2501 Magin Meadow Dr in Austin (TX)       Stray
# 1                 9409 Bluegrass Dr in Austin (TX)       Stray
# 2               2818 Palomino Trail in Austin (TX)       Stray
# 3                                      Austin (TX)       Stray
# 4                    800 Grove Blvd in Austin (TX)       Stray
# ...                                            ...         ...
# 136758  Cameron And Crosspark Drive in Austin (TX)       Stray
# 136759                   45 And 183 in Travis (TX)       Stray
# 136760        1200 Montopolis Drive in Austin (TX)       Stray
# 136761      7601 Daffan Ln Unit 424 in Austin (TX)       Stray
# 136762            8071 N Lamar Blvd in Austin (TX)       Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136758           Normal         Dog   Intact Female        6 months
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
#
#                                         Breed         Color MonthYear  \
# 0                                  Beagle Mix      Tricolor       NaN
# 1                    English Springer Spaniel   White/Liver       NaN
# 2                                 Basenji Mix   Sable/White       NaN
# 3                      Domestic Shorthair Mix        Calico       NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray       NaN
# ...                                       ...           ...       ...
# 136758                 Labrador Retriever Mix   Black/White       NaN
# 136759                         Great Pyrenees         White       NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White       NaN
# 136761                           Pit Bull Mix  White/Yellow       NaN
# 136762                             Cane Corso    Blue Cream       NaN
#
#              type  day of week  Intake Year
# 0       Stray Dog            3         2019
# 1       Stray Dog            6         2015
# 2       Stray Dog            3         2016
# 3       Stray Cat            0         2013
# 4       Stray Dog            6         2014
# ...           ...          ...          ...
# 136758  Stray Dog            0         2022
# 136759  Stray Dog            0         2022
# 136760  Stray Dog            1         2022
# 136761  Stray Dog            4         2022
# 136762  Stray Dog            6         2022
#
# [94180 rows x 16 columns]

# %%
# Check which rows have an intake year greater than or equal to 2020

animals.loc[animals['Intake Year'] >= 2020]
# Out:
#        Animal ID      Name               DateTime                Year  \
# 7        A844350     *Ella    2021-10-15 11:40:00 2021-10-15 11:40:00
# 9        A818975       NaN    2020-06-18 14:53:00 2020-06-18 14:53:00
# 22       A831808       NaN    2021-04-02 11:16:00 2021-04-02 11:16:00
# 24       A836850       NaN    2021-06-15 12:37:00 2021-06-15 12:37:00
# 26       A815227      Baby    2020-03-12 13:52:00 2020-03-12 13:52:00
# ...          ...       ...                    ...                 ...
# 136759   A852221      Coco    2022-02-28 11:05:00 2022-02-28 11:05:00
# 136760   A851977     *Jack    2022-02-22 13:34:00 2022-02-22 13:34:00
# 136761   A852127     Sonic    2022-02-25 13:05:00 2022-02-25 13:05:00
# 136762   A852194     Queen    2022-02-27 13:44:00 2022-02-27 13:44:00
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM 2022-02-28 11:25:00
#
#                                        Found Location      Intake Type  \
# 7       2112 East William Cannon Drive in Austin (TX)            Stray
# 9               Braker Lane And Metric in Travis (TX)            Stray
# 22                                        Austin (TX)  Owner Surrender
# 24                 6111 Softwood Drive in Austin (TX)    Public Assist
# 26                   12305 Zeller Lane in Austin (TX)            Stray
# ...                                               ...              ...
# 136759                      45 And 183 in Travis (TX)            Stray
# 136760           1200 Montopolis Drive in Austin (TX)            Stray
# 136761         7601 Daffan Ln Unit 424 in Austin (TX)            Stray
# 136762               8071 N Lamar Blvd in Austin (TX)            Stray
# 136763                                   Houston (TX)    Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 7                Normal         Cat   Intact Female        6 months
# 9                Normal         Cat     Intact Male         4 weeks
# 22               Normal         Cat   Intact Female         1 month
# 24             Pregnant         Dog   Intact Female         4 years
# 26               Normal         Dog   Intact Female         1 month
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                 Breed         Color      MonthYear  \
# 7                  Domestic Shorthair   Brown Tabby            NaN
# 9                  Domestic Shorthair   Cream Tabby            NaN
# 22             Domestic Shorthair Mix        Tortie            NaN
# 24                           Pit Bull    Blue/White            NaN
# 26                    Norfolk Terrier   Brown/Cream            NaN
# ...                               ...           ...            ...
# 136759                 Great Pyrenees         White            NaN
# 136760  Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                   Pit Bull Mix  White/Yellow            NaN
# 136762                     Cane Corso    Blue Cream            NaN
# 136763             Domestic Shorthair         Black  February 2022
#
#                        type  day of week  Intake Year
# 7                 Stray Cat            4         2021
# 9                 Stray Cat            3         2020
# 22      Owner Surrender Cat            4         2021
# 24        Public Assist Dog            1         2021
# 26                Stray Dog            3         2020
# ...                     ...          ...          ...
# 136759            Stray Dog            0         2022
# 136760            Stray Dog            1         2022
# 136761            Stray Dog            4         2022
# 136762            Stray Dog            6         2022
# 136763    Public Assist Cat            0         2022
#
# [23270 rows x 16 columns]

# %%
# Let's explore an interesting property of boolean columns...
# Find out the total sum of animals taken in during or after 2020
animals.loc[animals['Intake Year'] >= 2020].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23270 entries, 7 to 136763
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Animal ID         23270 non-null  object
#  1   Name              17719 non-null  object
#  2   DateTime          23270 non-null  object
#  3   Year              23270 non-null  datetime64[ns]
#  4   Found Location    23270 non-null  object
#  5   Intake Type       23270 non-null  object
#  6   Intake Condition  23270 non-null  object
#  7   Animal Type       23270 non-null  object
#  8   Sex upon Intake   23270 non-null  object
#  9   Age upon Intake   23270 non-null  object
#  10  Breed             23270 non-null  object
#  11  Color             23270 non-null  object
#  12  MonthYear         1 non-null      object
#  13  type              23270 non-null  object
#  14  day of week       23270 non-null  int64
#  15  Intake Year       23270 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(13)
# memory usage: 3.0+ MB

# %% [markdown]
# But this only gives us True/False outputs... what if we want to really filter?

# %% [markdown]
# ## `.loc`

# %% [markdown]
# We can locate and segment down to only rows where some condition is true using `.loc`. This takes in a condition, and only outputs the rows where that condition is True!
#
# > **Note:** locate (`.loc`) uses square brackets, not parentheses! Often, square brackets denote location-focused actions, like this one.
#
# Let's try this first with the condition we just built, and locate all animals taken in during or after 2020.

# %%
# Create a subset dataframe of animals taken in during or after 2020
subset_animals = animals[animals['Intake Year'] >= 2020]

# %%
# Sanity check
subset_animals
# Out:
#        Animal ID      Name               DateTime                Year  \
# 7        A844350     *Ella    2021-10-15 11:40:00 2021-10-15 11:40:00
# 9        A818975       NaN    2020-06-18 14:53:00 2020-06-18 14:53:00
# 22       A831808       NaN    2021-04-02 11:16:00 2021-04-02 11:16:00
# 24       A836850       NaN    2021-06-15 12:37:00 2021-06-15 12:37:00
# 26       A815227      Baby    2020-03-12 13:52:00 2020-03-12 13:52:00
# ...          ...       ...                    ...                 ...
# 136759   A852221      Coco    2022-02-28 11:05:00 2022-02-28 11:05:00
# 136760   A851977     *Jack    2022-02-22 13:34:00 2022-02-22 13:34:00
# 136761   A852127     Sonic    2022-02-25 13:05:00 2022-02-25 13:05:00
# 136762   A852194     Queen    2022-02-27 13:44:00 2022-02-27 13:44:00
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM 2022-02-28 11:25:00
#
#                                        Found Location      Intake Type  \
# 7       2112 East William Cannon Drive in Austin (TX)            Stray
# 9               Braker Lane And Metric in Travis (TX)            Stray
# 22                                        Austin (TX)  Owner Surrender
# 24                 6111 Softwood Drive in Austin (TX)    Public Assist
# 26                   12305 Zeller Lane in Austin (TX)            Stray
# ...                                               ...              ...
# 136759                      45 And 183 in Travis (TX)            Stray
# 136760           1200 Montopolis Drive in Austin (TX)            Stray
# 136761         7601 Daffan Ln Unit 424 in Austin (TX)            Stray
# 136762               8071 N Lamar Blvd in Austin (TX)            Stray
# 136763                                   Houston (TX)    Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 7                Normal         Cat   Intact Female        6 months
# 9                Normal         Cat     Intact Male         4 weeks
# 22               Normal         Cat   Intact Female         1 month
# 24             Pregnant         Dog   Intact Female         4 years
# 26               Normal         Dog   Intact Female         1 month
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                 Breed         Color      MonthYear  \
# 7                  Domestic Shorthair   Brown Tabby            NaN
# 9                  Domestic Shorthair   Cream Tabby            NaN
# 22             Domestic Shorthair Mix        Tortie            NaN
# 24                           Pit Bull    Blue/White            NaN
# 26                    Norfolk Terrier   Brown/Cream            NaN
# ...                               ...           ...            ...
# 136759                 Great Pyrenees         White            NaN
# 136760  Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                   Pit Bull Mix  White/Yellow            NaN
# 136762                     Cane Corso    Blue Cream            NaN
# 136763             Domestic Shorthair         Black  February 2022
#
#                        type  day of week  Intake Year
# 7                 Stray Cat            4         2021
# 9                 Stray Cat            3         2020
# 22      Owner Surrender Cat            4         2021
# 24        Public Assist Dog            1         2021
# 26                Stray Dog            3         2020
# ...                     ...          ...          ...
# 136759            Stray Dog            0         2022
# 136760            Stray Dog            1         2022
# 136761            Stray Dog            4         2022
# 136762            Stray Dog            6         2022
# 136763    Public Assist Cat            0         2022
#
# [23270 rows x 16 columns]

# %% [markdown]
# We can return only certain columns when we do this, by adding an argument after the condition:

# %%
# Let's return just the 'Animal ID', 'DateTime' and 'Type' columns
subset_animals.loc[:,['Animal ID','DateTime','type']]
# Out:
#        Animal ID               DateTime                 type
# 7        A844350    2021-10-15 11:40:00            Stray Cat
# 9        A818975    2020-06-18 14:53:00            Stray Cat
# 22       A831808    2021-04-02 11:16:00  Owner Surrender Cat
# 24       A836850    2021-06-15 12:37:00    Public Assist Dog
# 26       A815227    2020-03-12 13:52:00            Stray Dog
# ...          ...                    ...                  ...
# 136759   A852221    2022-02-28 11:05:00            Stray Dog
# 136760   A851977    2022-02-22 13:34:00            Stray Dog
# 136761   A852127    2022-02-25 13:05:00            Stray Dog
# 136762   A852194    2022-02-27 13:44:00            Stray Dog
# 136763   A851755  2/28/2022 11:25:00 AM    Public Assist Cat
#
# [23270 rows x 3 columns]

# %% [markdown]
# What if I want to segment using multiple conditions? Use `&` for "and" and `|` for "or" - and use parentheses around individual conditions!

# %%
# Find all the Stray Cats taken in during or after 2020
subset_animals.loc['type' == 'Stray Cat']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[146], line 2
#       1 # Find all the Stray Cats taken in during or after 2020
# ----> 2 subset_animals.loc['type' == 'Stray Cat']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1311, in _LocIndexer._getitem_axis(self, key, axis)
#    1308         return self.obj.iloc[tuple(indexer)]
#    1310 # fall thru to straight lookup
# -> 1311 self._validate_key(key, axis)
#    1312 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1118, in _LocIndexer._validate_key(self, key, axis)
#    1108 @doc(_LocationIndexer._validate_key)
#    1109 def _validate_key(self, key, axis: int):
#    1110     # valid for a collection of labels (we check their presence later)
#    1111     # slice of labels (where start-end in labels)
#    1112     # slice of integers (only if in the labels)
#    1113     # boolean not in slice and with boolean index
#    1114     if isinstance(key, bool) and not (
#    1115         is_bool_dtype(self.obj._get_axis(axis))
#    1116         or self.obj._get_axis(axis).dtype.name == "boolean"
#    1117     ):
# -> 1118         raise KeyError(
#    1119             f"{key}: boolean label can not be used without a boolean index"
#    1120         )
#    1122     if isinstance(key, slice) and (
#    1123         isinstance(key.start, bool) or isinstance(key.stop, bool)
#    1124     ):
#    1125         raise TypeError(f"{key}: boolean values can not be used in a slice")
#
# KeyError: 'False: boolean label can not be used without a boolean index'

# %%
animals.loc[(animals['Intake Type'] == 'Stray') & (animals['Intake Year'] >= 2020)]
# Out:
#        Animal ID      Name             DateTime                Year  \
# 7        A844350     *Ella  2021-10-15 11:40:00 2021-10-15 11:40:00
# 9        A818975       NaN  2020-06-18 14:53:00 2020-06-18 14:53:00
# 26       A815227      Baby  2020-03-12 13:52:00 2020-03-12 13:52:00
# 44       A821389  *Dim Sum  2020-08-10 14:10:00 2020-08-10 14:10:00
# 71       A813757       NaN  2020-02-18 12:26:00 2020-02-18 12:26:00
# ...          ...       ...                  ...                 ...
# 136758   A852238   A852238  2022-02-28 14:02:00 2022-02-28 14:02:00
# 136759   A852221      Coco  2022-02-28 11:05:00 2022-02-28 11:05:00
# 136760   A851977     *Jack  2022-02-22 13:34:00 2022-02-22 13:34:00
# 136761   A852127     Sonic  2022-02-25 13:05:00 2022-02-25 13:05:00
# 136762   A852194     Queen  2022-02-27 13:44:00 2022-02-27 13:44:00
#
#                                        Found Location Intake Type  \
# 7       2112 East William Cannon Drive in Austin (TX)       Stray
# 9               Braker Lane And Metric in Travis (TX)       Stray
# 26                   12305 Zeller Lane in Austin (TX)       Stray
# 44           7800 San Felipe Boulevard in Austin (TX)       Stray
# 71          Colonial Park And Weidemar in Austin (TX)       Stray
# ...                                               ...         ...
# 136758     Cameron And Crosspark Drive in Austin (TX)       Stray
# 136759                      45 And 183 in Travis (TX)       Stray
# 136760           1200 Montopolis Drive in Austin (TX)       Stray
# 136761         7601 Daffan Ln Unit 424 in Austin (TX)       Stray
# 136762               8071 N Lamar Blvd in Austin (TX)       Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 7                Normal         Cat   Intact Female        6 months
# 9                Normal         Cat     Intact Male         4 weeks
# 26               Normal         Dog   Intact Female         1 month
# 44               Normal         Cat     Intact Male         4 weeks
# 71               Normal         Dog   Intact Female          1 year
# ...                 ...         ...             ...             ...
# 136758           Normal         Dog   Intact Female        6 months
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
#
#                                         Breed           Color MonthYear  \
# 7                          Domestic Shorthair     Brown Tabby       NaN
# 9                          Domestic Shorthair     Cream Tabby       NaN
# 26                            Norfolk Terrier     Brown/Cream       NaN
# 44                         Domestic Shorthair     Brown Tabby       NaN
# 71      German Shepherd/Australian Cattle Dog  Black/Tricolor       NaN
# ...                                       ...             ...       ...
# 136758                 Labrador Retriever Mix     Black/White       NaN
# 136759                         Great Pyrenees           White       NaN
# 136760          Chihuahua Shorthair/Dachshund     Black/White       NaN
# 136761                           Pit Bull Mix    White/Yellow       NaN
# 136762                             Cane Corso      Blue Cream       NaN
#
#              type  day of week  Intake Year
# 7       Stray Cat            4         2021
# 9       Stray Cat            3         2020
# 26      Stray Dog            3         2020
# 44      Stray Cat            0         2020
# 71      Stray Dog            1         2020
# ...           ...          ...          ...
# 136758  Stray Dog            0         2022
# 136759  Stray Dog            0         2022
# 136760  Stray Dog            1         2022
# 136761  Stray Dog            4         2022
# 136762  Stray Dog            6         2022
#
# [14187 rows x 16 columns]

# %% [markdown]
# ### Your turn!

# %% [markdown]
# #### Exercise 1
#
# You need to find dogs that need extra attention - How would you find all dogs where the intake condition is NOT normal?

# %%
# Your code here

animals.loc[(animals['Animal Type'] == 'Dog') & (animals['Intake Condition'] != 'Normal')]
# Out:
#        Animal ID                Name             DateTime                Year  \
# 24       A836850                 NaN  2021-06-15 12:37:00 2021-06-15 12:37:00
# 38       A794334               Pearl  2019-09-02 11:52:00 2019-09-02 11:52:00
# 40       A732903              *Raven  2016-08-14 15:02:00 2016-08-14 15:02:00
# 91       A683884             Blackie  2014-07-16 15:52:00 2014-07-16 15:52:00
# 134      A818382              Cookie  2020-06-08 08:35:00 2020-06-08 08:35:00
# ...          ...                 ...                  ...                 ...
# 136723   A852080  *Marshmallow Fluff  2022-02-24 13:29:00 2022-02-24 13:29:00
# 136724   A852083              *Honey  2022-02-24 13:29:00 2022-02-24 13:29:00
# 136726   A852085            *Treacle  2022-02-24 13:29:00 2022-02-24 13:29:00
# 136728   A852084        *Maple Syrup  2022-02-24 13:29:00 2022-02-24 13:29:00
# 136742   A850725               Monty  2022-01-30 14:32:00 2022-01-30 14:32:00
#
#                               Found Location      Intake Type  \
# 24        6111 Softwood Drive in Austin (TX)    Public Assist
# 38                      Outside Jurisdiction  Owner Surrender
# 40                               Austin (TX)            Stray
# 91      7619 E Ben White Blvd in Austin (TX)            Stray
# 134       4434 Frontier Trail in Austin (TX)  Owner Surrender
# ...                                      ...              ...
# 136723       6911 Bennett Ave in Austin (TX)            Stray
# 136724       6911 Bennett Ave in Austin (TX)            Stray
# 136726       6911 Bennett Ave in Austin (TX)            Stray
# 136728       6911 Bennett Ave in Austin (TX)            Stray
# 136742       14100 Thermal Dr in Austin (TX)            Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 24             Pregnant         Dog   Intact Female         4 years
# 38                 Sick         Dog   Spayed Female         3 years
# 40              Injured         Dog   Intact Female        2 months
# 91              Injured         Dog   Neutered Male         2 years
# 134                Sick         Dog     Intact Male         1 month
# ...                 ...         ...             ...             ...
# 136723          Injured         Dog   Intact Female       10 months
# 136724          Injured         Dog   Intact Female        2 months
# 136726          Injured         Dog   Intact Female        2 months
# 136728          Injured         Dog   Intact Female        2 months
# 136742          Injured         Dog     Intact Male         2 years
#
#                          Breed        Color MonthYear                 type  \
# 24                    Pit Bull   Blue/White       NaN    Public Assist Dog
# 38                   Boxer Mix        White       NaN  Owner Surrender Dog
# 40      Labrador Retriever Mix  Black/White       NaN            Stray Dog
# 91         German Shepherd Mix    Black/Tan       NaN            Stray Dog
# 134                      Boxer  Brown/Black       NaN  Owner Surrender Dog
# ...                        ...          ...       ...                  ...
# 136723     German Shepherd Mix     Buff/Tan       NaN            Stray Dog
# 136724  Labrador Retriever Mix  Black/White       NaN            Stray Dog
# 136726      Labrador Retriever  Brown/White       NaN            Stray Dog
# 136728  Labrador Retriever Mix  Black/White       NaN            Stray Dog
# 136742      Labrador Retriever  Black/White       NaN            Stray Dog
#
#         day of week  Intake Year
# 24                1         2021
# 38                0         2019
# 40                6         2016
# 91                2         2014
# 134               0         2020
# ...             ...          ...
# 136723            3         2022
# 136724            3         2022
# 136726            3         2022
# 136728            3         2022
# 136742            6         2022
#
# [7526 rows x 16 columns]

# %% [markdown]
# #### Exercise 2
#
# You need to find animals that might need to be fixed - How would you find all animals that are either Intact Male or Intact Female?

# %%
# Your code here

animals.loc[(animals['Sex upon Intake'] == 'Intact Male') | (animals['Sex upon Intake'] == 'Intact Female')]
# Out:
#        Animal ID     Name             DateTime                Year  \
# 2        A724273  Runster  2016-04-14 18:43:00 2016-04-14 18:43:00
# 3        A665644      NaN  2013-10-21 07:59:00 2013-10-21 07:59:00
# 7        A844350    *Ella  2021-10-15 11:40:00 2021-10-15 11:40:00
# 8        A708452   Mumble  2015-07-30 14:37:00 2015-07-30 14:37:00
# 9        A818975      NaN  2020-06-18 14:53:00 2020-06-18 14:53:00
# ...          ...      ...                  ...                 ...
# 136758   A852238  A852238  2022-02-28 14:02:00 2022-02-28 14:02:00
# 136759   A852221     Coco  2022-02-28 11:05:00 2022-02-28 11:05:00
# 136760   A851977    *Jack  2022-02-22 13:34:00 2022-02-22 13:34:00
# 136761   A852127    Sonic  2022-02-25 13:05:00 2022-02-25 13:05:00
# 136762   A852194    Queen  2022-02-27 13:44:00 2022-02-27 13:44:00
#
#                                        Found Location    Intake Type  \
# 2                  2818 Palomino Trail in Austin (TX)          Stray
# 3                                         Austin (TX)          Stray
# 7       2112 East William Cannon Drive in Austin (TX)          Stray
# 8                                         Austin (TX)  Public Assist
# 9               Braker Lane And Metric in Travis (TX)          Stray
# ...                                               ...            ...
# 136758     Cameron And Crosspark Drive in Austin (TX)          Stray
# 136759                      45 And 183 in Travis (TX)          Stray
# 136760           1200 Montopolis Drive in Austin (TX)          Stray
# 136761         7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762               8071 N Lamar Blvd in Austin (TX)          Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 7                Normal         Cat   Intact Female        6 months
# 8                Normal         Dog     Intact Male         2 years
# 9                Normal         Cat     Intact Male         4 weeks
# ...                 ...         ...             ...             ...
# 136758           Normal         Dog   Intact Female        6 months
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
#
#                                 Breed         Color MonthYear  \
# 2                         Basenji Mix   Sable/White       NaN
# 3              Domestic Shorthair Mix        Calico       NaN
# 7                  Domestic Shorthair   Brown Tabby       NaN
# 8              Labrador Retriever Mix   Black/White       NaN
# 9                  Domestic Shorthair   Cream Tabby       NaN
# ...                               ...           ...       ...
# 136758         Labrador Retriever Mix   Black/White       NaN
# 136759                 Great Pyrenees         White       NaN
# 136760  Chihuahua Shorthair/Dachshund   Black/White       NaN
# 136761                   Pit Bull Mix  White/Yellow       NaN
# 136762                     Cane Corso    Blue Cream       NaN
#
#                      type  day of week  Intake Year
# 2               Stray Dog            3         2016
# 3               Stray Cat            0         2013
# 7               Stray Cat            4         2021
# 8       Public Assist Dog            3         2015
# 9               Stray Cat            3         2020
# ...                   ...          ...          ...
# 136758          Stray Dog            0         2022
# 136759          Stray Dog            0         2022
# 136760          Stray Dog            1         2022
# 136761          Stray Dog            4         2022
# 136762          Stray Dog            6         2022
#
# [87649 rows x 16 columns]

# %% [markdown]
# ## `.iloc`

# %% [markdown]
# `.iloc` is used for integer-location based indexing, aka locate by number. It can take in lists of numbers, python slices, or specific numbers - but sometimes it can be a bit tricky!

# %%
# Find the first 3 rows

animals.iloc[:3,:]
# Out:
#   Animal ID     Name             DateTime                Year  \
# 0   A786884   *Brock  2019-01-03 16:19:00 2019-01-03 16:19:00
# 1   A706918    Belle  2015-07-05 12:59:00 2015-07-05 12:59:00
# 2   A724273  Runster  2016-04-14 18:43:00 2016-04-14 18:43:00
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake                     Breed  \
# 0         Dog   Neutered Male         2 years                Beagle Mix
# 1         Dog   Spayed Female         8 years  English Springer Spaniel
# 2         Dog     Intact Male       11 months               Basenji Mix
#
#          Color MonthYear       type  day of week  Intake Year
# 0     Tricolor       NaN  Stray Dog            3         2019
# 1  White/Liver       NaN  Stray Dog            6         2015
# 2  Sable/White       NaN  Stray Dog            3         2016

# %%
# Same as using head(3)
animals.head(3)
# Out:
#   Animal ID     Name             DateTime                Year  \
# 0   A786884   *Brock  2019-01-03 16:19:00 2019-01-03 16:19:00
# 1   A706918    Belle  2015-07-05 12:59:00 2015-07-05 12:59:00
# 2   A724273  Runster  2016-04-14 18:43:00 2016-04-14 18:43:00
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake                     Breed  \
# 0         Dog   Neutered Male         2 years                Beagle Mix
# 1         Dog   Spayed Female         8 years  English Springer Spaniel
# 2         Dog     Intact Male       11 months               Basenji Mix
#
#          Color MonthYear       type  day of week  Intake Year
# 0     Tricolor       NaN  Stray Dog            3         2019
# 1  White/Liver       NaN  Stray Dog            6         2015
# 2  Sable/White       NaN  Stray Dog            3         2016

# %%
# Can look exactly where the 0 index is
animals.iloc[0,:]
# Out:
# Animal ID                                       A786884
# Name                                             *Brock
# DateTime                            2019-01-03 16:19:00
# Year                                2019-01-03 16:19:00
# Found Location      2501 Magin Meadow Dr in Austin (TX)
# Intake Type                                       Stray
# Intake Condition                                 Normal
# Animal Type                                         Dog
# Sex upon Intake                           Neutered Male
# Age upon Intake                                 2 years
# Breed                                        Beagle Mix
# Color                                          Tricolor
# MonthYear                                           NaN
# type                                          Stray Dog
# day of week                                           3
# Intake Year                                        2019
# Name: 0, dtype: object

# %%
# But what about our subset dataframe above? It doesn't have an index 0
subset_animals.head()
# Out:
#    Animal ID   Name             DateTime                Year  \
# 7    A844350  *Ella  2021-10-15 11:40:00 2021-10-15 11:40:00
# 9    A818975    NaN  2020-06-18 14:53:00 2020-06-18 14:53:00
# 22   A831808    NaN  2021-04-02 11:16:00 2021-04-02 11:16:00
# 24   A836850    NaN  2021-06-15 12:37:00 2021-06-15 12:37:00
# 26   A815227   Baby  2020-03-12 13:52:00 2020-03-12 13:52:00
#
#                                    Found Location      Intake Type  \
# 7   2112 East William Cannon Drive in Austin (TX)            Stray
# 9           Braker Lane And Metric in Travis (TX)            Stray
# 22                                    Austin (TX)  Owner Surrender
# 24             6111 Softwood Drive in Austin (TX)    Public Assist
# 26               12305 Zeller Lane in Austin (TX)            Stray
#
#    Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 7            Normal         Cat   Intact Female        6 months
# 9            Normal         Cat     Intact Male         4 weeks
# 22           Normal         Cat   Intact Female         1 month
# 24         Pregnant         Dog   Intact Female         4 years
# 26           Normal         Dog   Intact Female         1 month
#
#                      Breed        Color MonthYear                 type  \
# 7       Domestic Shorthair  Brown Tabby       NaN            Stray Cat
# 9       Domestic Shorthair  Cream Tabby       NaN            Stray Cat
# 22  Domestic Shorthair Mix       Tortie       NaN  Owner Surrender Cat
# 24                Pit Bull   Blue/White       NaN    Public Assist Dog
# 26         Norfolk Terrier  Brown/Cream       NaN            Stray Dog
#
#     day of week  Intake Year
# 7             4         2021
# 9             3         2020
# 22            4         2021
# 24            1         2021
# 26            3         2020

# %%
# Try it...
subset_animals.iloc[0,:]
# Out:
# Animal ID                                                 A844350
# Name                                                        *Ella
# DateTime                                      2021-10-15 11:40:00
# Year                                          2021-10-15 11:40:00
# Found Location      2112 East William Cannon Drive in Austin (TX)
# Intake Type                                                 Stray
# Intake Condition                                           Normal
# Animal Type                                                   Cat
# Sex upon Intake                                     Intact Female
# Age upon Intake                                          6 months
# Breed                                          Domestic Shorthair
# Color                                                 Brown Tabby
# MonthYear                                                     NaN
# type                                                    Stray Cat
# day of week                                                     4
# Intake Year                                                  2021
# Name: 7, dtype: object

# %% [markdown]
# # Series Methods

# %% [markdown]
# ## `.value_counts()`

# %% [markdown]
# How many different values does the Animal Type column have? What about Breed?

# %%
# Check the value counts for Animal Type
animals['Animal Type'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
# Now check Breed
animals['Breed'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# Sometimes, this is more useful than others... but, can check the percentage of the total, which might be more useful!

# %%
# Use the normalize argument to view as percentages
animals.loc[animals['Animal Type'] == 'Cat']['Breed'].value_counts(normalize = True)
# Out:
# Domestic Shorthair Mix                 0.618979
# Domestic Shorthair                     0.201747
# Domestic Medium Hair Mix               0.062122
# Domestic Longhair Mix                  0.030530
# Siamese Mix                            0.025989
#                                          ...
# Domestic Longhair/Domestic Longhair    0.000019
# Siamese/Angora                         0.000019
# Ocicat Mix                             0.000019
# Domestic Shorthair/Manx                0.000019
# Siamese/Domestic Medium Hair           0.000019
# Name: Breed, Length: 103, dtype: float64

# %% [markdown]
# ## `.sort_values()`
#
# As you can imagine, this works differently whether you're using it on a numeric or non-numeric column

# %%
# Let's sort the year column
animals['Intake Year'].sort_values(ascending = False)
# Out:
# 136763    2022
# 135598    2022
# 135600    2022
# 135601    2022
# 135603    2022
#           ...
# 114540    2013
# 7568      2013
# 6328      2013
# 114531    2013
# 96175     2013
# Name: Intake Year, Length: 136764, dtype: int64

# %%
animals.sort_values(by = 'Year', ascending = False)
# Out:
#        Animal ID     Name             DateTime                Year  \
# 136758   A852238  A852238  2022-02-28 14:02:00 2022-02-28 14:02:00
# 136752   A852219   Nieves  2022-02-28 13:41:00 2022-02-28 13:41:00
# 136754   A852234      NaN  2022-02-28 12:33:00 2022-02-28 12:33:00
# 136750   A852230      NaN  2022-02-28 12:15:00 2022-02-28 12:15:00
# 136748   A852225     Lucy  2022-02-28 12:13:00 2022-02-28 12:13:00
# ...          ...      ...                  ...                 ...
# 117647   A664233   Stevie  2013-10-01 08:53:00 2013-10-01 08:53:00
# 115905   A664236      NaN  2013-10-01 08:33:00 2013-10-01 08:33:00
# 2378     A664237      NaN  2013-10-01 08:33:00 2013-10-01 08:33:00
# 38976    A664235      NaN  2013-10-01 08:33:00 2013-10-01 08:33:00
# 72961    A521520     Nina  2013-10-01 07:51:00 2013-10-01 07:51:00
#
#                                     Found Location      Intake Type  \
# 136758  Cameron And Crosspark Drive in Austin (TX)            Stray
# 136752                   45 And 183 in Travis (TX)            Stray
# 136754              305 E Lola Lane in Austin (TX)            Stray
# 136750                                 Austin (TX)            Stray
# 136748                                 Travis (TX)  Owner Surrender
# ...                                            ...              ...
# 117647              7405 Springtime in Austin (TX)            Stray
# 115905                         Abia in Austin (TX)            Stray
# 2378                           Abia in Austin (TX)            Stray
# 38976                          Abia in Austin (TX)            Stray
# 72961                      Norht Ec in Austin (TX)            Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 136758           Normal         Dog   Intact Female        6 months
# 136752           Normal         Dog   Intact Female         3 years
# 136754          Injured         Cat   Intact Female         2 years
# 136750           Normal         Cat         Unknown        5 months
# 136748           Normal         Cat   Intact Female        3 months
# ...                 ...         ...             ...             ...
# 117647          Injured         Dog   Intact Female         3 years
# 115905           Normal         Cat         Unknown          1 week
# 2378             Normal         Cat         Unknown          1 week
# 38976            Normal         Cat         Unknown          1 week
# 72961            Normal         Dog   Spayed Female         7 years
#
#                                Breed         Color MonthYear  \
# 136758        Labrador Retriever Mix   Black/White       NaN
# 136752                Great Pyrenees         White       NaN
# 136754            Domestic Shorthair        Calico       NaN
# 136750            Domestic Shorthair   Brown Tabby       NaN
# 136748        Domestic Shorthair Mix         Black       NaN
# ...                              ...           ...       ...
# 117647                  Pit Bull Mix    Blue/White       NaN
# 115905        Domestic Shorthair Mix  Orange/White       NaN
# 2378          Domestic Shorthair Mix  Orange/White       NaN
# 38976         Domestic Shorthair Mix  Orange/White       NaN
# 72961   Border Terrier/Border Collie     White/Tan       NaN
#
#                        type  day of week  Intake Year
# 136758            Stray Dog            0         2022
# 136752            Stray Dog            0         2022
# 136754            Stray Cat            0         2022
# 136750            Stray Cat            0         2022
# 136748  Owner Surrender Cat            0         2022
# ...                     ...          ...          ...
# 117647            Stray Dog            1         2013
# 115905            Stray Cat            1         2013
# 2378              Stray Cat            1         2013
# 38976             Stray Cat            1         2013
# 72961             Stray Dog            1         2013
#
# [136764 rows x 16 columns]

# %%
# Now, sort the Animal Type col
animals['Animal Type'].sort_values
# Out:
# <bound method Series.sort_values of 0         Dog
# 1         Dog
# 2         Dog
# 3         Cat
# 4         Dog
#          ...
# 136759    Dog
# 136760    Dog
# 136761    Dog
# 136762    Dog
# 136763    Cat
# Name: Animal Type, Length: 136764, dtype: object>

# %%
# We can do this on the whole dataframe, it just needs to know what to sort by
animals.sort_values(by = 'Color')
# Out:
#        Animal ID       Name             DateTime                Year  \
# 105801   A734409      Halti  2016-09-06 11:45:00 2016-09-06 11:45:00
# 60605    A744737      Ellie  2017-03-06 17:58:00 2017-03-06 17:58:00
# 132479   A845418    A845418  2021-10-29 16:17:00 2021-10-29 16:17:00
# 68444    A842304  *Squirrel  2021-09-13 17:17:00 2021-09-13 17:17:00
# 132478   A845415    A845415  2021-10-29 16:17:00 2021-10-29 16:17:00
# ...          ...        ...                  ...                 ...
# 43385    A743409        Ray  2017-02-09 18:40:00 2017-02-09 18:40:00
# 127331   A784089    Juniper  2018-11-11 14:17:00 2018-11-11 14:17:00
# 66123    A660295       Blue  2014-08-14 10:38:00 2014-08-14 10:38:00
# 136391   A851523  *Honeybee  2022-02-14 11:44:00 2022-02-14 11:44:00
# 109598   A698632       Nalu  2015-03-17 13:33:00 2015-03-17 13:33:00
#
#                                            Found Location      Intake Type  \
# 105801                        5411 Gregg Ln in Manor (TX)            Stray
# 60605   Springtime Trl And Crepe Myrtle Drive in Austi...            Stray
# 132479                                        Austin (TX)  Owner Surrender
# 68444                 West 45Th And Lavaca in Austin (TX)            Stray
# 132478                                        Austin (TX)  Owner Surrender
# ...                                                   ...              ...
# 43385               12400 Mellow Meadow Dr in Austin (TX)            Stray
# 127331                   13021 Dessau Road in Austin (TX)            Stray
# 66123        10301 Little Pebble Dr Unit A in Austin (TX)  Owner Surrender
# 136391                     2937 Ellon Road in Travis (TX)            Stray
# 109598                                        Austin (TX)    Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 105801           Normal         Dog     Intact Male         2 years
# 60605            Normal         Dog   Intact Female        7 months
# 132479           Normal         Cat   Intact Female         1 month
# 68444            Normal         Cat   Intact Female         4 weeks
# 132478           Normal         Cat     Intact Male         1 month
# ...                 ...         ...             ...             ...
# 43385            Normal         Dog     Intact Male         6 years
# 127331           Normal         Dog   Intact Female         1 month
# 66123            Normal         Dog     Intact Male         2 years
# 136391           Normal         Dog   Intact Female        2 months
# 109598           Normal         Dog   Intact Female          1 year
#
#                          Breed          Color MonthYear                 type  \
# 105801      Siberian Husky Mix         Agouti       NaN            Stray Dog
# 60605       Siberian Husky Mix         Agouti       NaN            Stray Dog
# 132479      Domestic Shorthair         Agouti       NaN  Owner Surrender Cat
# 68444           Abyssinian Mix         Agouti       NaN            Stray Cat
# 132478      Domestic Shorthair         Agouti       NaN  Owner Surrender Cat
# ...                        ...            ...       ...                  ...
# 43385     Picardy Sheepdog Mix   Yellow/White       NaN            Stray Dog
# 127331  Labrador Retriever Mix   Yellow/White       NaN            Stray Dog
# 66123            Catahoula Mix   Yellow/White       NaN  Owner Surrender Dog
# 136391  Labrador Retriever Mix   Yellow/White       NaN            Stray Dog
# 109598           Finnish Spitz  Yellow/Yellow       NaN    Public Assist Dog
#
#         day of week  Intake Year
# 105801            1         2016
# 60605             0         2017
# 132479            4         2021
# 68444             0         2021
# 132478            4         2021
# ...             ...          ...
# 43385             3         2017
# 127331            6         2018
# 66123             3         2014
# 136391            0         2022
# 109598            1         2015
#
# [136764 rows x 16 columns]

# %% [markdown]
# # Extra Credit: Find a .csv file online and experiment with it.

# %% [markdown]
# Head to [dataportals.org](https://dataportals.org) to find a .csv file.

# %%
hi_df = pd.read_csv('https://data.honolulu.gov/resource/vg88-5rn5.csv')
hi_df.head()
# Out:
#    objectid  incidentnum                 blockaddress                    cmid  \
# 0    685775  230211-0333         2400 BLOCK S KING ST  Honolulu_PD_HI_5169630
# 1    689110  230215-0246  840400 BLOCK FARRINGTON HWY  Honolulu_PD_HI_5186083
# 2    689111  230215-0254          500 BLOCK N KING ST  Honolulu_PD_HI_5186105
# 3    689907  230210-0201       800 BLOCK KAPAHULU AVE  Honolulu_PD_HI_5164511
# 4    689908  230210-0203     940800 BLOCK LUMIAINA ST  Honolulu_PD_HI_5164520
#
#           cmagency                     date                 type status  \
# 0  Honolulu PD, HI  2023-02-11T05:52:10.000        THEFT/LARCENY      M
# 1  Honolulu PD, HI  2023-02-15T05:47:05.000              ASSAULT      M
# 2  Honolulu PD, HI  2023-02-15T05:54:41.000        THEFT/LARCENY      M
# 3  Honolulu PD, HI  2023-02-10T03:44:17.000        THEFT/LARCENY      M
# 4  Honolulu PD, HI  2023-02-10T03:46:39.000  MOTOR VEHICLE THEFT      M
#
#    score side
# 0    100    L
# 1    100    R
# 2    100    L
# 3    100    L
# 4    100    L

# %%
hi_df['date'] = pd.to_datetime(hi_df['date'])

# %%
hi_df
# Out:
#      objectid  incidentnum                 blockaddress  \
# 0      685775  230211-0333         2400 BLOCK S KING ST
# 1      689110  230215-0246  840400 BLOCK FARRINGTON HWY
# 2      689111  230215-0254          500 BLOCK N KING ST
# 3      689907  230210-0201       800 BLOCK KAPAHULU AVE
# 4      689908  230210-0203     940800 BLOCK LUMIAINA ST
# ..        ...          ...                          ...
# 995    696801  230219-1007          600 BLOCK KAIEMI ST
# 996    696802  230219-1033      2200 BLOCK KALAKAUA AVE
# 997    696803  230219-1039      2300 BLOCK AMOKEMOKE ST
# 998    696804  230219-1067  8200 BLOCK KALANIANAOLE HWY
# 999    696805  230219-1108      3200 BLOCK AHINAHINA PL
#
#                        cmid         cmagency                date  \
# 0    Honolulu_PD_HI_5169630  Honolulu PD, HI 2023-02-11 05:52:10
# 1    Honolulu_PD_HI_5186083  Honolulu PD, HI 2023-02-15 05:47:05
# 2    Honolulu_PD_HI_5186105  Honolulu PD, HI 2023-02-15 05:54:41
# 3    Honolulu_PD_HI_5164511  Honolulu PD, HI 2023-02-10 03:44:17
# 4    Honolulu_PD_HI_5164520  Honolulu PD, HI 2023-02-10 03:46:39
# ..                      ...              ...                 ...
# 995  Honolulu_PD_HI_5204218  Honolulu PD, HI 2023-02-19 12:39:13
# 996  Honolulu_PD_HI_5204256  Honolulu PD, HI 2023-02-19 12:52:06
# 997  Honolulu_PD_HI_5204268  Honolulu PD, HI 2023-02-19 12:56:16
# 998  Honolulu_PD_HI_5204319  Honolulu PD, HI 2023-02-19 13:09:48
# 999  Honolulu_PD_HI_5204409  Honolulu PD, HI 2023-02-19 13:32:56
#
#                        type status  score side
# 0             THEFT/LARCENY      M    100    L
# 1                   ASSAULT      M    100    R
# 2             THEFT/LARCENY      M    100    L
# 3             THEFT/LARCENY      M    100    L
# 4       MOTOR VEHICLE THEFT      M    100    L
# ..                      ...    ...    ...  ...
# 995  VEHICLE BREAK-IN/THEFT      M    100    R
# 996           THEFT/LARCENY      M    100    L
# 997           THEFT/LARCENY      M    100    L
# 998  VEHICLE BREAK-IN/THEFT      M    100    R
# 999           THEFT/LARCENY      M    100    L
#
# [1000 rows x 10 columns]
